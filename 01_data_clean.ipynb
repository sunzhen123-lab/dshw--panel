# %% [markdown]
# # 01 数据获取与清洗
#
# 执行与 `run_p03.py` 相同流程：原始数据写入 **`data/raw/`**，清洗后面板在 **`data/clean/panel_final.csv`**（AkShare 真实数据，非模拟）。

# %%
import os, sys
from pathlib import Path
ROOT = Path(".").resolve()
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from codes.paths import migrate_legacy_raw
from codes.fetch_real import download_raw
from codes.panel_build import build_panel

migrate_legacy_raw()
download_raw(force=False)
df = build_panel()
print(df.shape)
