# %% [markdown]
# # 02 描述性统计与相关分析
#
# 读取 `data/clean/panel_final.csv`；描述统计与 Fig.1–Fig.3 由 `codes/analysis_run.py` 在 `run_p03.py` 中一并生成；本笔记本可独立查看数据。

# %%
import pandas as pd

df = pd.read_csv("data/clean/panel_final.csv")
display(df.describe().T)
