# %% [markdown]
# # 03 面板回归与稳健性
#
# 回归结果文本见 `output/reg_*.txt`；图见 `output/figures/`。

# %%
import os, sys
from pathlib import Path
ROOT = Path(".").resolve()
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
import pandas as pd
from codes.paths import migrate_legacy_raw
from codes.analysis_run import run_all

migrate_legacy_raw()
df = pd.read_csv("data/clean/panel_final.csv")
run_all(df)
